# %%
import numpy as np
entradas = np.genfromtxt('../datasets/iris.data', delimiter=',', usecols=(0,1,2,3))
saidas = np.genfromtxt('../datasets/iris.data', delimiter=',', usecols=(4))
print(len(entradas))
print(len(saidas))
# Out:
# 150
# 150

# %%
'''
Iris setosa = 0
iris versicolor = 1
iris virginca = 2
'''

print(entradas[:5])
print(saidas[:5])

print('-------------------------')

print(entradas[-5:])
print(saidas[-5:])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0. 0. 0. 0. 0.]
# -------------------------
# [[6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# [2. 2. 2. 2. 2.]

# %%
# Reservando 105 amostras para treino, sendo 35 de cada

entradas_treino = np.concatenate((entradas[:35], entradas[50:85], entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35], saidas[50:85], saidas[100:135]))

print(len(entradas_treino))
print(len(saidas_treino))
# Out:
# 105
# 105

# %%
entradas_teste = np.concatenate((entradas[35:50], entradas[85:100], entradas[135:150])) 
saidas_teste = np.concatenate((saidas[35:50], saidas[85:100], saidas[135:150])) 

print(len(entradas_teste))
print(len(saidas_teste))
# Out:
# 45
# 45

# %%
from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4,1)
for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i], saidas_treino[i])
print(len(treinamento))
print(treinamento.indim)
print(treinamento.outdim)
# Out:
# 105
# 4
# 1

# %%
#Construindo a rede

rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.3)

#Treinando a rede
for epoca in range(1000):
    trainer.train()
    
    
#Testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.003 ]')
# ('correct:', '[0     ]')
# error:  0.00000381
# ('out:    ', '[-0.031]')
# ('correct:', '[0     ]')
# error:  0.00048482
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012379
# ('out:    ', '[0.065 ]')
# ('correct:', '[0     ]')
# error:  0.00210180
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00009143
# ('out:    ', '[0.022 ]')
# ('correct:', '[0     ]')
# error:  0.00023634
# ('out:    ', '[0.168 ]')
# ('correct:', '[0     ]')
# error:  0.01408649
# ('out:    ', '[0.048 ]')
# ('correct:', '[0     ]')
# error:  0.00114772
# ('out:    ', '[0.18  ]')
# ('correct:', '[0     ]')
# error:  0.01615366
# ('out:    ', '[0.098 ]')
# ('correct:', '[0     ]')
# error:  0.00482914
# ('out:    ', '[0.088 ]')
# ('correct:', '[0     ]')
# error:  0.00388938
# ('out:    ', '[-0.004]')
# ('correct:', '[0     ]')
# error:  0.00000936
# ('out:    ', '[0.047 ]')
# ('correct:', '[0     ]')
# error:  0.00111315
# ('out:    ', '[-0.017]')
# ('correct:', '[0     ]')
# error:  0.00014250
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012673
# ('out:    ', '[1.151 ]')
# ('correct:', '[1     ]')
# error:  0.01136792
# ('out:    ', '[1.135 ]')
# ('correct:', '[1     ]')
# error:  0.00914618
# ('out:    ', '[1.273 ]')
# ('correct:', '[1     ]')
# error:  0.03717328
# ('out:    ', '[1.033 ]')
# ('correct:', '[1     ]')
# error:  0.00053794
# ('out:    ', '[1.18  ]')
# ('correct:', '[1     ]')
# error:  0.01616711
# ('out:    ', '[1.32  ]')
# ('correct:', '[1     ]')
# error:  0.05134874
# ('out:    ', '[1.22  ]')
# ('correct:', '[1     ]')
# error:  0.02409862
# ('out:    ', '[1.018 ]')
# ('correct:', '[1     ]')
# error:  0.00015479
# ('out:    ', '[0.88  ]')
# ('correct:', '[1     ]')
# error:  0.00719806
# ('out:    ', '[1.187 ]')
# ('correct:', '[1     ]')
# error:  0.01757393
# ('out:    ', '[1.005 ]')
# ('correct:', '[1     ]')
# error:  0.00001329
# ('out:    ', '[1.088 ]')
# ('correct:', '[1     ]')
# error:  0.00391152
# ('out:    ', '[1.024 ]')
# ('correct:', '[1     ]')
# error:  0.00029029
# ('out:    ', '[0.789 ]')
# ('correct:', '[1     ]')
# error:  0.02221529
# ('out:    ', '[1.074 ]')
# ('correct:', '[1     ]')
# error:  0.00271535
# ('out:    ', '[2.075 ]')
# ('correct:', '[2     ]')
# error:  0.00281226
# ('out:    ', '[2.07  ]')
# ('correct:', '[2     ]')
# error:  0.00244872
# ('out:    ', '[1.889 ]')
# ('correct:', '[2     ]')
# error:  0.00621394
# ('out:    ', '[1.631 ]')
# ('correct:', '[2     ]')
# error:  0.06790115
# ('out:    ', '[1.857 ]')
# ('correct:', '[2     ]')
# error:  0.01029321
# ('out:    ', '[2.074 ]')
# ('correct:', '[2     ]')
# error:  0.00277203
# ('out:    ', '[1.791 ]')
# ('correct:', '[2     ]')
# error:  0.02185857
# ('out:    ', '[1.997 ]')
# ('correct:', '[2     ]')
# error:  0.00000445
# ('out:    ', '[2.097 ]')
# ('correct:', '[2     ]')
# error:  0.00465867
# ('out:    ', '[2.087 ]')
# ('correct:', '[2     ]')
# error:  0.00381072
# ('out:    ', '[1.927 ]')
# ('correct:', '[2     ]')
# error:  0.00265729
# ('out:    ', '[1.915 ]')
# ('correct:', '[2     ]')
# error:  0.00363056
# ('out:    ', '[1.84  ]')
# ('correct:', '[2     ]')
# error:  0.01279390
# ('out:    ', '[1.993 ]')
# ('correct:', '[2     ]')
# error:  0.00002238
# ('out:    ', '[1.841 ]')
# ('correct:', '[2     ]')
# error:  0.01258703
# ('All errors:', [3.808031608779787e-06, 0.000484821554488801, 0.00012379078842965097, 0.002101799539881212, 9.142674431885235e-05, 0.00023633554850588427, 0.01408649280616739, 0.0011477185691271662, 0.016153655114155212, 0.004829136546939177, 0.003889383466448434, 9.361807579082927e-06, 0.0011131501230671435, 0.0001424973748205886, 0.00012673065006751384, 0.011367916811828619, 0.00914618282498051, 0.037173282856570206, 0.0005379382901595935, 0.016167110368069858, 0.05134874306770198, 0.024098622435932842, 0.0001547882728397411, 0.0071980641943596045, 0.017573931766028096, 1.3289469810047671e-05, 0.003911517597388037, 0.0002902879520547627, 0.022215290057253895, 0.002715352478986296, 0.0028122582664250008, 0.002448722670274593, 0.006213937926666693, 0.0679011508395426, 0.010293211703408326, 0.0027720288652365904, 0.021858568772890316, 4.449257976815519e-06, 0.004658667494755417, 0.0038107176835801503, 0.002657294490051632, 0.003630559236382803, 0.012793901905718233, 2.237680010098984e-05, 0.012587029575227861])
# ('Average error:', 0.00895371783550682)
# ('Max error:', 0.0679011508395426, 'Median error:', 0.003630559236382803)
# 0.00895371783550682

# %%
#Construindo a rede

rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.5)

#Treinando a rede
for epoca in range(1000):
    trainer.train()
    
    
#Testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00013146
# ('out:    ', '[0.011 ]')
# ('correct:', '[0     ]')
# error:  0.00006317
# ('out:    ', '[0.021 ]')
# ('correct:', '[0     ]')
# error:  0.00021556
# ('out:    ', '[0.026 ]')
# ('correct:', '[0     ]')
# error:  0.00034499
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00014179
# ('out:    ', '[0.015 ]')
# ('correct:', '[0     ]')
# error:  0.00011770
# ('out:    ', '[0.06  ]')
# ('correct:', '[0     ]')
# error:  0.00180852
# ('out:    ', '[0.021 ]')
# ('correct:', '[0     ]')
# error:  0.00023072
# ('out:    ', '[0.032 ]')
# ('correct:', '[0     ]')
# error:  0.00051346
# ('out:    ', '[0.022 ]')
# ('correct:', '[0     ]')
# error:  0.00024277
# ('out:    ', '[0.03  ]')
# ('correct:', '[0     ]')
# error:  0.00043709
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00007646
# ('out:    ', '[0.022 ]')
# ('correct:', '[0     ]')
# error:  0.00024327
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00006880
# ('out:    ', '[0.018 ]')
# ('correct:', '[0     ]')
# error:  0.00015422
# ('out:    ', '[1.022 ]')
# ('correct:', '[1     ]')
# error:  0.00024586
# ('out:    ', '[1.081 ]')
# ('correct:', '[1     ]')
# error:  0.00324181
# ('out:    ', '[1.279 ]')
# ('correct:', '[1     ]')
# error:  0.03904615
# ('out:    ', '[0.857 ]')
# ('correct:', '[1     ]')
# error:  0.01023742
# ('out:    ', '[1.106 ]')
# ('correct:', '[1     ]')
# error:  0.00566616
# ('out:    ', '[1.166 ]')
# ('correct:', '[1     ]')
# error:  0.01379724
# ('out:    ', '[1.107 ]')
# ('correct:', '[1     ]')
# error:  0.00576187
# ('out:    ', '[0.908 ]')
# ('correct:', '[1     ]')
# error:  0.00426717
# ('out:    ', '[0.705 ]')
# ('correct:', '[1     ]')
# error:  0.04349712
# ('out:    ', '[1.076 ]')
# ('correct:', '[1     ]')
# error:  0.00291216
# ('out:    ', '[0.805 ]')
# ('correct:', '[1     ]')
# error:  0.01905394
# ('out:    ', '[0.944 ]')
# ('correct:', '[1     ]')
# error:  0.00154743
# ('out:    ', '[0.906 ]')
# ('correct:', '[1     ]')
# error:  0.00446221
# ('out:    ', '[0.544 ]')
# ('correct:', '[1     ]')
# error:  0.10374126
# ('out:    ', '[0.95  ]')
# ('correct:', '[1     ]')
# error:  0.00124085
# ('out:    ', '[2.011 ]')
# ('correct:', '[2     ]')
# error:  0.00005812
# ('out:    ', '[1.959 ]')
# ('correct:', '[2     ]')
# error:  0.00082903
# ('out:    ', '[1.73  ]')
# ('correct:', '[2     ]')
# error:  0.03657535
# ('out:    ', '[1.555 ]')
# ('correct:', '[2     ]')
# error:  0.09879395
# ('out:    ', '[1.808 ]')
# ('correct:', '[2     ]')
# error:  0.01842808
# ('out:    ', '[1.996 ]')
# ('correct:', '[2     ]')
# error:  0.00000707
# ('out:    ', '[1.822 ]')
# ('correct:', '[2     ]')
# error:  0.01592556
# ('out:    ', '[1.863 ]')
# ('correct:', '[2     ]')
# error:  0.00934282
# ('out:    ', '[1.993 ]')
# ('correct:', '[2     ]')
# error:  0.00002633
# ('out:    ', '[2.005 ]')
# ('correct:', '[2     ]')
# error:  0.00001195
# ('out:    ', '[1.898 ]')
# ('correct:', '[2     ]')
# error:  0.00515184
# ('out:    ', '[1.848 ]')
# ('correct:', '[2     ]')
# error:  0.01151010
# ('out:    ', '[1.77  ]')
# ('correct:', '[2     ]')
# error:  0.02635211
# ('out:    ', '[1.881 ]')
# ('correct:', '[2     ]')
# error:  0.00707188
# ('out:    ', '[1.69  ]')
# ('correct:', '[2     ]')
# error:  0.04816562
# ('All errors:', [0.0001314630639629884, 6.317027991394138e-05, 0.00021555663433378506, 0.0003449903914125911, 0.0001417909838617388, 0.00011770414357273098, 0.0018085189343653675, 0.00023072085498636996, 0.0005134557940334737, 0.00024277256004400294, 0.00043708500557859844, 7.646324067432116e-05, 0.00024327171215936656, 6.87986580821303e-05, 0.00015421719330893958, 0.0002458601073418748, 0.003241809287195465, 0.03904615129469382, 0.010237415519785926, 0.005666163922355181, 0.013797244273251122, 0.005761871440853439, 0.004267173886419637, 0.043497119167709215, 0.0029121635957993866, 0.019053939224628398, 0.0015474344593451378, 0.00446220684002698, 0.10374126117814843, 0.0012408476421875419, 5.812151697519205e-05, 0.000829026982234217, 0.03657534768004012, 0.09879395033598135, 0.0184280812117443, 7.065562957355195e-06, 0.01592555919846561, 0.009342816346466071, 2.633284776503275e-05, 1.1948307362674706e-05, 0.005151837905593803, 0.011510101256172287, 0.02635210664734541, 0.007071875858139191, 0.04816561939548558])
# ('Average error:', 0.012039076274283555)
# ('Max error:', 0.10374126117814843, 'Median error:', 0.0018085189343653675)
# 0.012039076274283555
