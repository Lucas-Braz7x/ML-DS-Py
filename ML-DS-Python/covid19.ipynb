# %%
# %matplotlib inline
import pandas as pd
import pydataset
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (11,7)

# %%
df = pd.read_csv('./datasets/rio_covid19.csv')

# %%
df.head()
# Out:
#          Date      Hour       Neighborhood  Cases  Deaths  Recovered
# 0  2020-04-21  18:00:00           ABOLICAO      5       1          2
# 1  2020-04-21  18:00:00              ACARI      8       1          3
# 2  2020-04-21  18:00:00         AGUA SANTA      1       0          1
# 3  2020-04-21  18:00:00  ALTO DA BOA VISTA      6       1          1
# 4  2020-04-21  18:00:00           ANCHIETA     27       1         11

# %%
plt.plot(df['Cases'], df['Date'], '-b')
plt.plot(df['Deaths'], df['Date'], '-r')
plt.plot(df['Recovered'], df['Date'], '-g')
plt.show()

# %%
df.plot()
